# %%
import cv2 as cv
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
import os
import seaborn as sns
import pandas as pd

class Visual_BOW():
    def __init__(self, k=20, dictionary_size=50):
        self.k = k  # number of SIFT features to extract from every image
        self.dictionary_size = dictionary_size  # size of your "visual dictionary" (k in k-means)
        self.n_tests = 1  # how many times to re-run the same algorithm (to obtain average accuracy)

    def extract_sift_features(self):
        '''
        To Do:
            - load/read the Caltech-101 dataset
            - go through all the images and extract "k" SIFT features from every image
            - divide the data into training/testing (70% of images should go to the training set, 30% to testing)
        Useful:
            k: number of SIFT features to extract from every image
        Output:
            train_features: list/array of size n_images_train x k x feature_dim
            train_labels: list/array of size n_images_train
            test_features: list/array of size n_images_test x k x feature_dim
            test_labels: list/array of size n_images_test
        '''
        path = os.getcwd() + '/101_ObjectCategories'

        labels = []
        features = []
        sift = cv.xfeatures2d.SIFT_create(self.k)

        for root, directories, files in os.walk(path):
            if root == path:
                pass
            else:
                #print(files)
                print(directories)
                print(root)
                print(os.path.basename(root))
                for file in files:
                    image = root + '/' + file
                    img = cv.imread(image)
                    keypoints, desc = sift.detectAndCompute(img, None)
                    if desc is not None:
                        labels.append(os.path.basename(root))
                        features.append(desc[:self.k])

        data = list(zip(labels, features))
        random.shuffle(data)
        labels, features = zip(*data)
        train_features = []
        train_labels = []
        test_features = []
        test_labels = []

        for index in range(len(labels)):
            if index < .7 * len(labels):
                train_features.append(features[index])
                train_labels.append(labels[index])
            else:
                test_features.append(features[index])
                test_labels.append(labels[index])



        return train_features, train_labels, test_features, test_labels

    def create_dictionary(self, features):
        '''
        To Do:
            - go through the list of features
            - flatten it to be of size (n_images x k) x feature_dim (from 3D to 2D)
            - use k-means algorithm to group features into "dictionary_size" groups
        Useful:
            dictionary_size: size of your "visual dictionary" (k in k-means)
        Input:
            features: list/array of size n_images x k x feature_dim
        Output:
            kmeans: trained k-means object (algorithm trained on the flattened feature list)
        '''
        ''' Recognize that this might not be the best approach (should make 20 X 128)
            feature vector earlier
        '''

        flattened = []
        for feature in features:
            for index in range(len(feature)):
                flattened.append(feature[index])

        kmeans = KMeans(n_clusters=self.dictionary_size, random_state=0).fit(flattened)

        return kmeans

    def convert_features_using_dictionary(self, kmeans, features):
        '''
        To Do:
            - go through the list of features (images)
            - for every image go through "k" SIFT features that describes it
            - every image will be described by a single vector of length "dictionary_size"
            and every entry in that vector will indicate how many times a SIFT feature from a particular
            "visual group" (one of "dictionary_size") appears in the image. Non-appearing features are set to zeros.
        Input:
            features: list/array of size n_images x k x feature_dim
        Output:
            features_new: list/array of size n_images x dictionary_size
        '''
        # attempt one
        features_new = []
        for feature in features:
            image_count = np.zeros(self.dictionary_size)
            for index in range(len(feature)):
                image = feature[index].reshape(1,-1)
                image_count[kmeans.predict(image)[0]] += 1
            features_new.append(image_count)
        return features_new

    def train_svm(self, inputs, labels):
        '''
        To Do:
            - train an SVM classifier using the data
            - return the trained object
        Input:
            inputs: new features (converted using the dictionary) of size n_images x dictionary_size
            labels: list/array of size n_images
        Output:
            clf: trained svm classifier object (algorithm trained on the inputs/labels data)
        '''
        clf = svm.SVC()
        clf.fit(inputs, labels)
        return clf

    def test_svm(self, clf, inputs, labels):
        '''
        To Do:
            - test the previously trained SVM classifier using the data
            - calculate the accuracy of your model
        Input:
            clf: trained svm classifier object (algorithm trained on the inputs/labels data)
            inputs: new features (converted using the dictionary) of size n_images x dictionary_size
            labels: list/array of size n_images
        Output:
            accuracy: percent of correctly predicted samples
        '''

        num_correct = 0
        for index in range(len(inputs)):
            print(clf.predict(inputs[index].reshape(1,-1))[0])
            if clf.predict(inputs[index].reshape(1,-1))[0] == labels[index]:
                num_correct += 1

        accuracy = num_correct / len(labels)
        return accuracy

    def save_plot(self, features, labels):
        '''
        To Do:
            - perform PCA on your features
            - use only 2 first Principle Components to visualize the data (scatter plot)
            - color-code the data according to the ground truth label
            - save the plot
        Input:
            features: new features (converted using the dictionary) of size n_images x dictionary_size
            labels: list/array of size n_images
        '''
        pca = PCA(n_components=2)
        pca.fit(features)
        NUM_COLORS = 102
        cm = plt.get_cmap('gist_rainbow')
        #df = dict(PCA1=features @ pca.components_.T[:,0], PCA2=features @ pca.components_.T[:,1],
        colors=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)]
        labels_unique = list(set(labels))
        dictionary_colors = dict(zip(labels_unique, colors))
        print(labels_unique)
        print(len(labels_unique))
        #print(len(dictionary_colors))
        #sns.scatterplot('PCA1', 'PCA2', data=df, hue='color', legend=False)
        plt.scatter(features @ pca.components_.T[:,0], features @ pca.components_.T[:,1], c=[dictionary_colors[label] for label in labels])
        plt.savefig('PCA.png')

############################################################################
################## DO NOT MODIFY ANYTHING BELOW THIS LINE ##################
############################################################################

    def algorithm(self):
        # This is the main function used to run the program
        # DO NOT MODIFY THIS FUNCTION
        accuracy = 0.0
        for i in range(self.n_tests):
            train_features, train_labels, test_features, test_labels = self.extract_sift_features()
            kmeans = self.create_dictionary(train_features)
            train_features_new = self.convert_features_using_dictionary(kmeans, train_features)
            classifier = self.train_svm(train_features_new, train_labels)
            test_features_new = self.convert_features_using_dictionary(kmeans, test_features)
            accuracy += self.test_svm(classifier, test_features_new, test_labels)
            self.save_plot(test_features_new, test_labels)
        accuracy /= self.n_tests
        return accuracy

# %%
bow2 = Visual_BOW(k=2, dictionary_size=10)

# %%
train_features, train_labels, test_features, test_labels = bow2.extract_sift_features()
kmeans = bow2.create_dictionary(train_features)
train_features_new = bow2.convert_features_using_dictionary(kmeans, train_features)
classifier = bow2.train_svm(train_features_new, train_labels)
test_features_new = bow2.convert_features_using_dictionary(kmeans, test_features)
# Out:
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/gerenuk
# gerenuk
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/hawksbill
# hawksbill
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/headphone
# headphone
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/ant
# ant
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/butterfly
# butterfly
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/lamp
# lamp
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/strawberry
# strawberry
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/water_lilly
# water_lilly
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/chandelier
# chandelier
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/dragonfly
# dragonfly
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/crab
# crab
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/pagoda
# pagoda
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/dollar_bill
# dollar_bill
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/emu
# emu
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/inline_skate
# inline_skate
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/platypus
# platypus
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/dalmatian
# dalmatian
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/cup
# cup
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/airplanes
# airplanes
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/joshua_tree
# joshua_tree
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/cougar_body
# cougar_body
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/grand_piano
# grand_piano
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/trilobite
# trilobite
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/brontosaurus
# brontosaurus
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/wild_cat
# wild_cat
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/pigeon
# pigeon
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/dolphin
# dolphin
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/soccer_ball
# soccer_ball
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/wrench
# wrench
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/scorpion
# scorpion
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/flamingo_head
# flamingo_head
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/nautilus
# nautilus
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/accordion
# accordion
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/cougar_face
# cougar_face
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/pyramid
# pyramid
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/camera
# camera
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/barrel
# barrel
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/schooner
# schooner
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/cellphone
# cellphone
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/panda
# panda
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/revolver
# revolver
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/lobster
# lobster
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/menorah
# menorah
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/lotus
# lotus
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/stapler
# stapler
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/crocodile
# crocodile
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/chair
# chair
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/helicopter
# helicopter
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/minaret
# minaret
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/starfish
# starfish
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/ceiling_fan
# ceiling_fan
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/ketch
# ketch
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/mayfly
# mayfly
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/wheelchair
# wheelchair
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/bass
# bass
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/yin_yang
# yin_yang
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/crocodile_head
# crocodile_head
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/saxophone
# saxophone
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/beaver
# beaver
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/mandolin
# mandolin
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/bonsai
# bonsai
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/Leopards
# Leopards
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/car_side
# car_side
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/ibis
# ibis
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/electric_guitar
# electric_guitar
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/kangaroo
# kangaroo
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/stegosaurus
# stegosaurus
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/ferry
# ferry
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/snoopy
# snoopy
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/umbrella
# umbrella
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/rhino
# rhino
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/okapi
# okapi
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/watch
# watch
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/brain
# brain
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/gramophone
# gramophone
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/scissors
# scissors
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/rooster
# rooster
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/cannon
# cannon
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/binocular
# binocular
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/anchor
# anchor
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/octopus
# octopus
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/buddha
# buddha
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/laptop
# laptop
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/windsor_chair
# windsor_chair
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/hedgehog
# hedgehog
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/pizza
# pizza
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/euphonium
# euphonium
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/stop_sign
# stop_sign
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/Motorbikes
# Motorbikes
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/sea_horse
# sea_horse
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/flamingo
# flamingo
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/BACKGROUND_Google
# BACKGROUND_Google
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/ewer
# ewer
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/garfield
# garfield
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/crayfish
# crayfish
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/Faces_easy
# Faces_easy
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/Faces
# Faces
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/sunflower
# sunflower
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/llama
# llama
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/elephant
# elephant
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/tick
# tick
# []
# /Users/max/school/cs165b/final_project/101_ObjectCategories/metronome
# metronome

# %%
bow2.save_plot(test_features_new, test_labels)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-94a5fa468c03> in <module>
# ----> 1 bow2.save_plot(test_features_new, test_labels)
#
# <ipython-input-4-90683058f604> in save_plot(self, features, labels)
#     180
#     181         #sns.scatterplot('PCA1', 'PCA2', data=df, hue='color', legend=False)
# --> 182         plt.scatter(features @ pca.components_.T[:,0], features @ pca.components_.T[:,1], c=[dictionary_colors[label] for label in labels])
#     183         plt.savefig('PCA.png')
#     184
#
# <ipython-input-4-90683058f604> in <listcomp>(.0)
#     180
#     181         #sns.scatterplot('PCA1', 'PCA2', data=df, hue='color', legend=False)
# --> 182         plt.scatter(features @ pca.components_.T[:,0], features @ pca.components_.T[:,1], c=[dictionary_colors[label] for label in labels])
#     183         plt.savefig('PCA.png')
#     184
#
# KeyError: 'ant'

# %%
bow3 = Visual_BOW(k=2, dictionary_size=10)

# %%
bow3.save_plot(test_features_new, test_labels)
# Out:
# ['windsor_chair', 'brain', 'strawberry', 'gerenuk', 'garfield', 'butterfly', 'scissors', 'BACKGROUND_Google', 'stop_sign', 'starfish', 'crab', 'metronome', 'crayfish', 'sea_horse', 'accordion', 'yin_yang', 'trilobite', 'pagoda', 'ewer', 'headphone', 'camera', 'dolphin', 'pyramid', 'cellphone', 'cougar_face', 'inline_skate', 'chandelier', 'ketch', 'lamp', 'ceiling_fan', 'gramophone', 'bonsai', 'emu', 'ibis', 'cougar_body', 'hedgehog', 'umbrella', 'mayfly', 'crocodile_head', 'crocodile', 'lotus', 'stapler', 'joshua_tree', 'flamingo', 'chair', 'kangaroo', 'platypus', 'Motorbikes', 'menorah', 'elephant', 'rhino', 'stegosaurus', 'Faces_easy', 'car_side', 'airplanes', 'ferry', 'saxophone', 'minaret', 'pigeon', 'sunflower', 'wild_cat', 'hawksbill', 'water_lilly', 'flamingo_head', 'mandolin', 'bass', 'okapi', 'wrench', 'grand_piano', 'snoopy', 'cannon', 'panda', 'anchor', 'laptop', 'dalmatian', 'helicopter', 'barrel', 'llama', 'lobster', 'pizza', 'binocular', 'soccer_ball', 'dollar_bill', 'wheelchair', 'rooster', 'electric_guitar', 'Leopards', 'nautilus', 'tick', 'octopus', 'dragonfly', 'scorpion', 'revolver', 'schooner', 'euphonium', 'brontosaurus', 'cup', 'watch', 'buddha', 'beaver', 'Faces', 'ant']
# 102
