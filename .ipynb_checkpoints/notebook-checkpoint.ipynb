# %%
# import image names 
import os
import random
path = os.getcwd() + '/101_ObjectCategories'

images = {}
for root, directories, files in os.walk(path):
    if root == '/Users/max/school/cs165b/final_project/101_ObjectCategories':
        for directory in directories:
            images[directory] = []
    else:
        indicies = random.sample(range(0, len(files)), 30)
        images[os.path.basename(root)] = [files[index] for index in indicies]

# %%
# go through all the images and extract "k" SIFT features from every image
# Out:
# 'final_project'

# %%
k_features = 20
sample_path = os.getcwd() + '/101_ObjectCategories/water_lilly/image_0006.jpg'
sift = cv.xfeatures2d.SIFT_create(k_features)

# %%
sift
# Out:
# <xfeatures2d_SIFT 0x119440970>

# %%
img = cv.imread(sample_path)
keypoints = sift.detect(img)
len(keypoints)
# Out:
# 21

# %%
# Extract the Sift Features from each object
train_features = []
train_labels = [] 
test_features = []
test_labels = []
sift = cv.xfeatures2d.SIFT_create(k_features)

for category in images:
    print(category)
    train_labels.append(category)
    test_labels.append(category)
    data = []
    
    for image in images[category]: 
        #print(image)
        img = cv.imread(os.getcwd() + '/101_ObjectCategories/' + '/' + category + '/' + image)
        
        keypoints, desc = sift.detectAndCompute(img,None)
        data.append(desc[:k_features])
        print(len(desc[:k_features]))
    random.shuffle(data)
    train_features.append(data[:21])
    test_features.append(data[21:])
# Out:
# gerenuk
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# hawksbill
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# headphone
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# ant
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# butterfly
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# lamp
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# strawberry
# 20
# 20
# 20
# 20
# 20
# ...

# %%
len(train_features)
# Out:
# 102

# %%
len(train_features[10])
# Out:
# 21

# %%
sample_feature = np.array(train_features[3])
type(sample_feature)
# Out:
# numpy.ndarray

# %%
np.shape(sample_feature)
# Out:
# (21,)

# %%
# train features is a list of 101 sets of k images for with n descriptors for each image

# %%
def create_dictionary(self, features):
        '''
        To Do:
            - go through the list of features
            - flatten it to be of size (n_images x k) x feature_dim (from 3D to 2D)
            - use k-means algorithm to group features into "dictionary_size" groups
        Useful:
            dictionary_size: size of your "visual dictionary" (k in k-means)
        Input:
            features: list/array of size n_images x k x feature_dim
        Output:
            kmeans: trained k-means object (algorithm trained on the flattened feature list)
        '''
        

        return kmeans

# %%
print(np.shape(train_features))
train_features[1]
# Out:
# (102, 21)
# [array([[ 6.,  7.,  6., ...,  0.,  0.,  1.],
#         [ 6.,  2.,  1., ..., 16.,  4.,  3.],
#         [ 7.,  4.,  5., ..., 53., 35., 16.],
#         ...,
#         [84., 16.,  3., ...,  0.,  0.,  2.],
#         [29., 24., 24., ..., 10.,  7., 13.],
#         [20., 24., 11., ..., 22., 42., 13.]], dtype=float32),
#  array([[19.,  1.,  0., ..., 17., 51., 23.],
#         [79., 46.,  7., ..., 21., 27., 38.],
#         [20., 10.,  9., ..., 55., 20.,  8.],
#         ...,
#         [26., 24., 11., ...,  5.,  8., 77.],
#         [ 1.,  6., 16., ..., 21., 78., 21.],
#         [30.,  6.,  6., ...,  3.,  6.,  3.]], dtype=float32),
#  array([[ 7.,  8., 21., ..., 74., 14.,  3.],
#         [27., 50., 14., ...,  0.,  0.,  0.],
#         [44., 49., 29., ..., 80., 16., 14.],
#         ...,
#         [26., 22.,  3., ..., 33.,  0.,  2.],
#         [ 1.,  8., 26., ..., 24., 19., 39.],
#         [18., 10.,  4., ..., 87., 65., 25.]], dtype=float32),
# ...

# %%
# flatten features
features = []
num_samples = 0
for category in train_features:
    for image in category:
        
        if len(image) != 20:
            pass
        else:
            num_samples += 1
            features.append(np.array(image))
features = np.array(features)
features_fit = features.reshape(num_samples, np.shape(features)[1]*np.shape(features)[2])

# %%
np.shape(features_fit)
# Out:
# (2140, 2560)

# %%
kmeans = KMeans(n_clusters=50, random_state=0).fit(features_fit)

# %%
np.shape(features_fit[1].reshape(1,-1))
# Out:
# (1, 2560)

# %%
kmeans.predict(features_fit[].reshape(1,-1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-212-a4aebf12df76> in <module>
# ----> 1 kmeans.predict(features_fit.reshape(1,-1))
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in predict(self, X, sample_weight)
#    1085         check_is_fitted(self)
#    1086
# -> 1087         X = self._check_test_data(X)
#    1088         x_squared_norms = row_norms(X, squared=True)
#    1089         return _labels_inertia(X, sample_weight, x_squared_norms,
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in _check_test_data(self, X)
#     815             raise ValueError("Incorrect number of features. "
#     816                              "Got %d features, expected %d" % (
# --> 817                                  n_features, expected_n_features))
#     818
#     819         return X
#
# ...

# %%
features2
for feature in features:
    if len(feature) != 20:
        print(len(feature))
        print("false")

# %%
len(features)
# Out:
# 20

# %%
from sklearn.cluster import KMeans
np.shape(features[0])
# Out:
# (128,)

# %%
np.shape(features[0][1])
# Out:
# (128,)

# %%
features[0][0]
# Out:
# array([ 22.,   0.,   2.,  45.,  35.,  17.,  39.,  49.,  45.,   1.,   1.,
#          3.,  44.,  70.,  22.,  76., 125.,   3.,   0.,   1.,  14.,  27.,
#          6.,  98.,  24.,   1.,   1.,   1.,  24.,  56.,  18.,  17.,  29.,
#          1.,   1.,  22.,  42.,  27.,  39., 125.,  48.,  14.,   2.,  56.,
#        125.,  33.,  14.,  87., 125.,  54.,   2.,  12.,  19.,   8.,   5.,
#         76.,  29.,   4.,   1.,   9.,  50.,  18.,  22.,  32.,  39.,  49.,
#          2.,   3.,   8.,  11.,  17.,  32.,  29.,   4.,   0.,  19.,  67.,
#         78., 125.,  72., 111.,   7.,   9.,  14.,   5.,   9.,  69., 125.,
#         19.,   2.,  19.,  42.,  87.,   5.,   5.,  26.,  97.,  85.,   3.,
#          2.,   2.,   0.,   1.,   5., 105.,  18.,   1.,  14.,   8.,   3.,
#         47.,  41.,   4.,   1.,  19.,  86.,  20.,   0.,  24.,  26.,  11.,
#          9.,  32.,  29.,  35.,   6.,   0.,   6.], dtype=float32)

# %%
kmeans = KMeans(n_clusters=50, random_state=0).fit(features)

# %%
X = np.array([[1, 2], [1, 4], [1, 0],
              [10, 2], [10, 4], [10, 0]])
print(np.shape(X))
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
kmeans.labels_
x = [[0, 0], [12, 3]]
print(np.shape(x))
kmeans.predict(x)
# Out:
# (6, 2)
# (2, 2)
# array([1, 0], dtype=int32)
